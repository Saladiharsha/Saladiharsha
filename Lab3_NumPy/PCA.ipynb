# %% [markdown]
# # PCA Classification Project
#
# **Name:** Saladi Harsha Veera Rama Chandra
# **Student ID:** 0625601
#
# ---

# %% [markdown]
# ## Problem Statement
#
# This project aims to apply Principal Component Analysis (PCA) to reduce the dimensionality of the dataset and evaluate how it affects the performance of classification models.
#
# Key goals:
# - Reduce feature space using PCA
# - Train classification models
# - Compare performance before and after PCA

# %% [markdown]
# ## Dataset Description
#
# The dataset used in this project contains features used for classification. It is preprocessed and scaled before applying PCA.

# %% [markdown]
# ## PCA Explained
#
# PCA (Principal Component Analysis) is a dimensionality reduction technique that transforms features into a smaller set of components while preserving maximum variance.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot PCA explained variance
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance Explained')
plt.title('PCA Variance Explained')
plt.grid()
plt.show()

# %% [markdown]
# ## Model Evaluation
#
# The following metrics are used:
# - Accuracy
# - Confusion Matrix
# - Classification Report

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print('Accuracy:', accuracy_score(y_test, y_pred))
print('\nConfusion Matrix:\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))

# %% [markdown]
# ## Model Comparison
#
# Different models are compared based on their accuracy and performance metrics.

# %%
# Example comparison (update with your models)
models = ['Model1', 'Model2']
accuracies = [0.8, 0.85]

import matplotlib.pyplot as plt
plt.bar(models, accuracies)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Comparison')
plt.show()

# %% [markdown]
# ## Conclusion
#
# - PCA helps in reducing dimensionality and improving efficiency.
# - It may improve or slightly reduce accuracy depending on the dataset.
# - The best model is selected based on evaluation metrics.
#
# Overall, PCA is useful for simplifying models and improving performance when dealing with high-dimensional data.

# %% [markdown]
# # PCA Classification Lab
# Wine Dataset using PCA and KNN

# %% [markdown]
# ## Import Libraries

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load Dataset

# %%
data = load_wine()
X = data.data
y = data.target

print("Dataset shape:", X.shape)

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))

# %% [markdown]
# ## Standardize Data

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Data standardized")

# %% [markdown]
# ## KNN Before PCA

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred_before = knn.predict(X_test_scaled)
acc_before = accuracy_score(y_test, y_pred_before)

print("Accuracy BEFORE PCA:", acc_before)

# %% [markdown]
# ## Apply PCA

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)

# %% [markdown]
# ## KNN After PCA

# %%
knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)

y_pred_after = knn_pca.predict(X_test_pca)
acc_after = accuracy_score(y_test, y_pred_after)

print("Accuracy AFTER PCA:", acc_after)
